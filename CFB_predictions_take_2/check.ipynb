# %%
import pandas as pd

df = pd.read_csv("../CFB_predictions_take_2/post_calc_data/combined_data.csv")
df["team_opp.1"].head()
# Out:
# 0    San José State
# 1       Boise State
# 2        New Mexico
# 3              Navy
# 4        Utah State
# Name: team_opp.1, dtype: object
